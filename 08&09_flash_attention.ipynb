# %% [markdown]
# $S = Q*K^{T}$

# %% [markdown]
# the dimension of the matrix Q is T * d
# the dimension of the matrix K is T * d
# the dimension of the matrix S is T * T

# %% [markdown]
# $P_{ij} = \frac{e^{s_{ij}}}{\sum_{j=1}e^{s_{ij}}}$

# %% [markdown]
# the dimension of matrix P is T * T
# the dimension of matrix V is T * d

# %% [markdown]
# final result is $P * V$ is T * d dimension

# %% [markdown]
# flash attention try to minimize access to HBM
